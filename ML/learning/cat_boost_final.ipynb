# %%
# 필요한 라이브러리 임포트
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
from catboost import CatBoostClassifier

# %%
# 데이터 로드 및 전처리
df = pd.read_csv('../../csv/visit_all_in_one.csv', low_memory=False)
df_filter = df[~df['TRAVEL_MISSION_CHECK'].isnull()].copy()
df_filter['TRAVEL_MISSION_INT'] = df_filter['TRAVEL_MISSION_CHECK'].str.split(';').str[0].astype(int)

# %%
# 학습 데이터 준비
df_learning = df_filter[[
    'GENDER', 'AGE_GRP', 'TRAVEL_STYL_1', 'TRAVEL_STYL_2', 'TRAVEL_STYL_3',
    'TRAVEL_STYL_4', 'TRAVEL_STYL_5', 'TRAVEL_STYL_6', 'TRAVEL_STYL_7',
    'TRAVEL_STYL_8', 'TRAVEL_MOTIVE_1', 'TRAVEL_COMPANIONS_NUM',
    'TRAVEL_MISSION_INT', 'VISIT_AREA_NM', 'VISIT_AREA_TYPE_CD', 'DGSTFN'
]].dropna()

df_learning['GENDER'] = df_learning['GENDER'].replace({'남': 1, '여': 0}).astype('int32')
df_learning = df_learning[df_learning['VISIT_AREA_TYPE_CD'].isin(range(1, 9))]

# 범주형 변수 목록
cat_features = [
    'GENDER', 'AGE_GRP', 'TRAVEL_STYL_1', 'TRAVEL_STYL_2', 'TRAVEL_STYL_3',
    'TRAVEL_STYL_4', 'TRAVEL_STYL_5', 'TRAVEL_STYL_6', 'TRAVEL_STYL_7',
    'TRAVEL_STYL_8', 'TRAVEL_MOTIVE_1', 'VISIT_AREA_TYPE_CD',
    'TRAVEL_COMPANIONS_NUM', 'TRAVEL_MISSION_INT'
]

df_learning['TRAVEL_COMPANIONS_NUM'].unique()
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_2740\3506806361.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_learning['GENDER'] = df_learning['GENDER'].replace({'남': 1, '여': 0}).astype('int32')
# array([ 0.,  1.,  3.,  2.,  4.,  5.,  7.,  6., 11.,  9., 20.,  8., 14.,
#        19., 10., 12., 13., 16., 15., 17.])

# %%
# VISIT_AREA_NM을 숫자 코드로 변환
le = LabelEncoder()
df_learning['VISIT_AREA_NM_CODE'] = le.fit_transform(df_learning['VISIT_AREA_NM'])

# 학습에 사용할 특징
cat_features_extended = cat_features + ['VISIT_AREA_NM_CODE']
X = df_learning[cat_features_extended].astype('int32')
y = df_learning['DGSTFN']

# SMOTE 적용
# 3.0 샘플 늘려 클래스 간 경계 명확화:
smote = SMOTE(sampling_strategy={1.0: 2000, 2.0: 2000, 3.0: 6000}, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
X_resampled = np.round(X_resampled).astype('int32')

# 학습/테스트 데이터 분리
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.2, random_state=42
)

# 학습 데이터에서 검증 셋 분리 (early_stopping_rounds용)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=0.2, random_state=42
)

# %%
# 하이퍼파라미터 그리드 정의 (l2_leaf_reg 증가, 범위 축소)
param_grid = {
    'iterations': [400, 500, 600],  # 500 근처 탐색
    'learning_rate': [0.05, 0.1],   # 0.1 근처 탐색
    'depth': [8],                   # 최적값 고정
    'l2_leaf_reg': [5, 7, 10]      # 5~10으로 증가
}

class_weights = {1.0: 1, 2.0: 1, 3.0: 2, 4.0: 1, 5.0: 1.5}  # 5.0에 높은 가중치
# CatBoost 모델 초기화 (early_stopping_rounds 추가)
base_model = CatBoostClassifier(
    loss_function='MultiClass', # MultiClass 대신 MultiClassOneVsAll 사용 → 5.0을 이진 분류처럼 강화:
    eval_metric='Accuracy',
    cat_features=cat_features_extended,
    random_seed=42,
    task_type='GPU',
    early_stopping_rounds=50,  # 50번 동안 개선 없으면 중단
    class_weights=class_weights,
    verbose=100
)

# GridSearchCV 설정
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid,
    cv=3,
    scoring='accuracy',
    n_jobs=1,  # GPU 사용 시 병렬 처리는 단일 작업으로 (설명 아래 참고)
    verbose=2
)

# GridSearchCV 실행 (검증 셋 전달)
print("Starting GridSearchCV with early stopping and increased l2_leaf_reg...")
grid_search.fit(X_train, y_train, eval_set=(X_val, y_val))

# 최적 파라미터 및 성능 출력
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)

# 테스트 셋으로 최종 평가
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
print("Test Set Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Starting GridSearchCV with early stopping and increased l2_leaf_reg...
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 22.8ms	remaining: 9.08s
# 100:	learn: 0.5316291	test: 0.5055785	best: 0.5055785 (100)	total: 1.86s	remaining: 5.5s
# 200:	learn: 0.5690412	test: 0.5137270	best: 0.5140404 (199)	total: 3.58s	remaining: 3.54s
# 300:	learn: 0.6065477	test: 0.5184907	best: 0.5194309 (273)	total: 5.32s	remaining: 1.75s
# 399:	learn: 0.6447151	test: 0.5208098	best: 0.5219381 (380)	total: 7.03s	remaining: 0us
# bestTest = 0.521938072
# bestIteration = 380
# Shrink model to first 381 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=5, learning_rate=0.05; total time=   7.8s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 20.3ms	remaining: 8.12s
# 100:	learn: 0.5250673	test: 0.5039489	best: 0.5041369 (98)	total: 1.82s	remaining: 5.39s
# 200:	learn: 0.5621253	test: 0.5092140	best: 0.5103422 (179)	total: 3.74s	remaining: 3.71s
# 300:	learn: 0.6006940	test: 0.5166729	best: 0.5166729 (300)	total: 5.59s	remaining: 1.84s
# 399:	learn: 0.6349667	test: 0.5172997	best: 0.5193682 (377)	total: 7.27s	remaining: 0us
# bestTest = 0.5193681835
# bestIteration = 377
# Shrink model to first 378 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=5, learning_rate=0.05; total time=   7.9s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 19.3ms	remaining: 7.71s
# 100:	learn: 0.5379768	test: 0.5036981	best: 0.5045130 (92)	total: 1.97s	remaining: 5.82s
# 200:	learn: 0.5743958	test: 0.5156074	best: 0.5159835 (182)	total: 4.09s	remaining: 4.05s
# bestTest = 0.5159834524
# bestIteration = 182
# Shrink model to first 183 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=5, learning_rate=0.05; total time=   5.2s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 18.3ms	remaining: 7.31s
# 100:	learn: 0.5763348	test: 0.5136016	best: 0.5155447 (89)	total: 2.14s	remaining: 6.35s
# 200:	learn: 0.6423311	test: 0.5201203	best: 0.5211859 (188)	total: 4.02s	remaining: 3.98s
# bestTest = 0.5211859095
# bestIteration = 188
# Shrink model to first 189 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=5, learning_rate=0.1; total time=   5.3s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.7ms	remaining: 7.06s
# 100:	learn: 0.5669405	test: 0.5166729	best: 0.5183653 (99)	total: 1.86s	remaining: 5.52s
# bestTest = 0.5213112699
# bestIteration = 146
# Shrink model to first 147 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=5, learning_rate=0.1; total time=   4.3s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18ms	remaining: 7.2s
# 100:	learn: 0.5801784	test: 0.5114705	best: 0.5127868 (93)	total: 1.69s	remaining: 4.99s
# 200:	learn: 0.6519071	test: 0.5168610	best: 0.5179265 (163)	total: 3.33s	remaining: 3.29s
# 300:	learn: 0.7160593	test: 0.5218754	best: 0.5235678 (282)	total: 4.97s	remaining: 1.64s
# bestTest = 0.526513727
# bestIteration = 345
# Shrink model to first 346 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=5, learning_rate=0.1; total time=   7.1s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 17.6ms	remaining: 7.01s
# 100:	learn: 0.5279705	test: 0.5011909	best: 0.5023818 (97)	total: 1.72s	remaining: 5.08s
# 200:	learn: 0.5660435	test: 0.5102796	best: 0.5114705 (181)	total: 3.37s	remaining: 3.34s
# 300:	learn: 0.5923618	test: 0.5114705	best: 0.5138523 (282)	total: 4.99s	remaining: 1.64s
# 399:	learn: 0.6240145	test: 0.5172997	best: 0.5183026 (391)	total: 6.61s	remaining: 0us
# bestTest = 0.51830262
# bestIteration = 391
# Shrink model to first 392 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=7, learning_rate=0.05; total time=   7.2s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.6ms	remaining: 7.01s
# 100:	learn: 0.5239107	test: 0.5067695	best: 0.5067695 (100)	total: 1.71s	remaining: 5.06s
# 200:	learn: 0.5531322	test: 0.5134136	best: 0.5144164 (184)	total: 3.34s	remaining: 3.31s
# bestTest = 0.5162968535
# bestIteration = 235
# Shrink model to first 236 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=7, learning_rate=0.05; total time=   5.3s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.1ms	remaining: 7.23s
# 100:	learn: 0.5285593	test: 0.5028206	best: 0.5039489 (97)	total: 1.73s	remaining: 5.13s
# 200:	learn: 0.5653559	test: 0.5132882	best: 0.5133509 (199)	total: 3.42s	remaining: 3.39s
# 300:	learn: 0.6000047	test: 0.5184907	best: 0.5191801 (252)	total: 5.11s	remaining: 1.68s
# bestTest = 0.5191801429
# bestIteration = 252
# Shrink model to first 253 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=7, learning_rate=0.05; total time=   5.7s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 18.1ms	remaining: 7.23s
# 100:	learn: 0.5699146	test: 0.5114705	best: 0.5119719 (98)	total: 1.72s	remaining: 5.1s
# 200:	learn: 0.6259973	test: 0.5176131	best: 0.5197443 (164)	total: 3.37s	remaining: 3.34s
# bestTest = 0.5213739501
# bestIteration = 209
# Shrink model to first 210 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=7, learning_rate=0.1; total time=   4.9s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 19.6ms	remaining: 7.82s
# 100:	learn: 0.5561771	test: 0.5128494	best: 0.5136643 (95)	total: 2.02s	remaining: 5.98s
# 200:	learn: 0.6171694	test: 0.5129748	best: 0.5174878 (168)	total: 3.78s	remaining: 3.75s
# bestTest = 0.5174877774
# bestIteration = 168
# Shrink model to first 169 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=7, learning_rate=0.1; total time=   4.7s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 19.4ms	remaining: 7.74s
# 100:	learn: 0.5719883	test: 0.5130375	best: 0.5143538 (92)	total: 1.86s	remaining: 5.5s
# 200:	learn: 0.6362113	test: 0.5174251	best: 0.5189921 (166)	total: 3.55s	remaining: 3.51s
# bestTest = 0.5189921023
# bestIteration = 166
# Shrink model to first 167 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=7, learning_rate=0.1; total time=   4.4s
# 0:	learn: 0.4961526	test: 0.4919769	best: 0.4919769 (0)	total: 17.6ms	remaining: 7s
# 100:	learn: 0.5222348	test: 0.5023192	best: 0.5028206 (99)	total: 1.73s	remaining: 5.13s
# 200:	learn: 0.5567436	test: 0.5114078	best: 0.5114078 (183)	total: 3.38s	remaining: 3.35s
# 300:	learn: 0.5797810	test: 0.5115958	best: 0.5123480 (274)	total: 5.01s	remaining: 1.65s
# 399:	learn: 0.6042817	test: 0.5192428	best: 0.5197443 (393)	total: 7.02s	remaining: 0us
# bestTest = 0.5197442648
# bestIteration = 393
# Shrink model to first 394 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=10, learning_rate=0.05; total time=   7.6s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.6ms	remaining: 7.01s
# 100:	learn: 0.5189067	test: 0.5045130	best: 0.5045130 (97)	total: 1.91s	remaining: 5.64s
# 200:	learn: 0.5472785	test: 0.5110317	best: 0.5110317 (200)	total: 3.68s	remaining: 3.64s
# 300:	learn: 0.5712364	test: 0.5142284	best: 0.5142284 (300)	total: 5.4s	remaining: 1.77s
# bestTest = 0.5154820108
# bestIteration = 330
# Shrink model to first 331 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=10, learning_rate=0.05; total time=   7.3s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18ms	remaining: 7.18s
# 100:	learn: 0.5229418	test: 0.5031967	best: 0.5046383 (96)	total: 1.71s	remaining: 5.05s
# 200:	learn: 0.5595497	test: 0.5122226	best: 0.5134136 (198)	total: 3.35s	remaining: 3.32s
# 300:	learn: 0.5883450	test: 0.5170490	best: 0.5179892 (273)	total: 4.97s	remaining: 1.63s
# 399:	learn: 0.6158185	test: 0.5213740	best: 0.5213740 (399)	total: 6.95s	remaining: 0us
# bestTest = 0.5213739501
# bestIteration = 399
# [CV] END depth=8, iterations=400, l2_leaf_reg=10, learning_rate=0.05; total time=   7.6s
# 0:	learn: 0.4961526	test: 0.4919769	best: 0.4919769 (0)	total: 17.7ms	remaining: 7.08s
# 100:	learn: 0.5622669	test: 0.5112824	best: 0.5115958 (97)	total: 1.84s	remaining: 5.45s
# bestTest = 0.516171493
# bestIteration = 138
# Shrink model to first 139 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=10, learning_rate=0.1; total time=   3.9s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 18ms	remaining: 7.2s
# 100:	learn: 0.5517632	test: 0.5089633	best: 0.5094647 (88)	total: 1.87s	remaining: 5.53s
# 200:	learn: 0.5987348	test: 0.5112824	best: 0.5124734 (194)	total: 3.52s	remaining: 3.48s
# 300:	learn: 0.6490818	test: 0.5174878	best: 0.5179892 (293)	total: 5.18s	remaining: 1.7s
# 399:	learn: 0.6931266	test: 0.5189294	best: 0.5221261 (377)	total: 6.82s	remaining: 0us
# bestTest = 0.5221261126
# bestIteration = 377
# Shrink model to first 378 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=10, learning_rate=0.1; total time=   7.5s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 19.1ms	remaining: 7.61s
# 100:	learn: 0.5618863	test: 0.5141030	best: 0.5141030 (100)	total: 1.99s	remaining: 5.9s
# 200:	learn: 0.6170695	test: 0.5154820	best: 0.5165476 (158)	total: 3.75s	remaining: 3.71s
# 300:	learn: 0.6646290	test: 0.5203711	best: 0.5223142 (282)	total: 5.52s	remaining: 1.81s
# bestTest = 0.5223141532
# bestIteration = 282
# Shrink model to first 283 iterations.
# [CV] END depth=8, iterations=400, l2_leaf_reg=10, learning_rate=0.1; total time=   6.7s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 17.6ms	remaining: 8.81s
# 100:	learn: 0.5316291	test: 0.5055785	best: 0.5055785 (100)	total: 1.86s	remaining: 7.34s
# 200:	learn: 0.5690412	test: 0.5137270	best: 0.5140404 (199)	total: 3.53s	remaining: 5.25s
# 300:	learn: 0.6065477	test: 0.5184907	best: 0.5194309 (273)	total: 5.18s	remaining: 3.42s
# 400:	learn: 0.6451636	test: 0.5197443	best: 0.5219381 (380)	total: 6.83s	remaining: 1.69s
# bestTest = 0.521938072
# bestIteration = 380
# Shrink model to first 381 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time=   7.9s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.3ms	remaining: 8.65s
# 100:	learn: 0.5250673	test: 0.5039489	best: 0.5041369 (98)	total: 2.11s	remaining: 8.34s
# 200:	learn: 0.5621253	test: 0.5092140	best: 0.5103422 (179)	total: 3.95s	remaining: 5.87s
# 300:	learn: 0.6006940	test: 0.5166729	best: 0.5166729 (300)	total: 5.73s	remaining: 3.79s
# 400:	learn: 0.6353680	test: 0.5170490	best: 0.5193682 (377)	total: 7.63s	remaining: 1.88s
# bestTest = 0.5193681835
# bestIteration = 377
# Shrink model to first 378 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time=   8.7s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.4ms	remaining: 9.18s
# 100:	learn: 0.5379768	test: 0.5036981	best: 0.5045130 (92)	total: 1.83s	remaining: 7.22s
# 200:	learn: 0.5743958	test: 0.5156074	best: 0.5159835 (182)	total: 3.47s	remaining: 5.17s
# bestTest = 0.5159834524
# bestIteration = 182
# Shrink model to first 183 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time=   4.6s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 17.6ms	remaining: 8.8s
# 100:	learn: 0.5763348	test: 0.5136016	best: 0.5155447 (89)	total: 1.71s	remaining: 6.75s
# 200:	learn: 0.6423311	test: 0.5201203	best: 0.5211859 (188)	total: 3.91s	remaining: 5.81s
# bestTest = 0.5211859095
# bestIteration = 188
# Shrink model to first 189 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time=   5.2s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.5ms	remaining: 8.75s
# 100:	learn: 0.5669405	test: 0.5167983	best: 0.5183653 (99)	total: 1.83s	remaining: 7.23s
# bestTest = 0.5211859095
# bestIteration = 146
# Shrink model to first 147 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time=   4.1s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.2ms	remaining: 9.08s
# 100:	learn: 0.5801784	test: 0.5114705	best: 0.5127868 (93)	total: 1.84s	remaining: 7.27s
# 200:	learn: 0.6519071	test: 0.5168610	best: 0.5179265 (163)	total: 3.53s	remaining: 5.25s
# 300:	learn: 0.7160593	test: 0.5218754	best: 0.5235678 (282)	total: 5.18s	remaining: 3.43s
# bestTest = 0.526513727
# bestIteration = 345
# Shrink model to first 346 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.1; total time=   7.4s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 18.5ms	remaining: 9.22s
# 100:	learn: 0.5279705	test: 0.5011909	best: 0.5023818 (97)	total: 2.09s	remaining: 8.25s
# 200:	learn: 0.5660435	test: 0.5102796	best: 0.5114705 (181)	total: 3.95s	remaining: 5.88s
# 300:	learn: 0.5923618	test: 0.5114705	best: 0.5138523 (282)	total: 5.72s	remaining: 3.78s
# 400:	learn: 0.6248879	test: 0.5170490	best: 0.5183026 (391)	total: 7.5s	remaining: 1.85s
# bestTest = 0.51830262
# bestIteration = 391
# Shrink model to first 392 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05; total time=   8.8s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.7ms	remaining: 8.82s
# 100:	learn: 0.5239107	test: 0.5067695	best: 0.5067695 (100)	total: 1.71s	remaining: 6.74s
# 200:	learn: 0.5531322	test: 0.5134136	best: 0.5144164 (184)	total: 3.35s	remaining: 4.98s
# bestTest = 0.5162968535
# bestIteration = 235
# Shrink model to first 236 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05; total time=   5.4s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 17.9ms	remaining: 8.94s
# 100:	learn: 0.5285593	test: 0.5028206	best: 0.5039489 (97)	total: 1.72s	remaining: 6.78s
# 200:	learn: 0.5653559	test: 0.5132882	best: 0.5133509 (199)	total: 3.71s	remaining: 5.52s
# 300:	learn: 0.6000047	test: 0.5184907	best: 0.5191801 (252)	total: 5.49s	remaining: 3.63s
# bestTest = 0.5191801429
# bestIteration = 252
# Shrink model to first 253 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05; total time=   6.1s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 18ms	remaining: 8.99s
# 100:	learn: 0.5699146	test: 0.5114705	best: 0.5119719 (98)	total: 1.84s	remaining: 7.26s
# 200:	learn: 0.6259973	test: 0.5176131	best: 0.5197443 (164)	total: 3.67s	remaining: 5.46s
# bestTest = 0.5213739501
# bestIteration = 209
# Shrink model to first 210 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.1; total time=   5.2s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.5ms	remaining: 8.71s
# 100:	learn: 0.5561771	test: 0.5128494	best: 0.5136643 (95)	total: 1.68s	remaining: 6.64s
# 200:	learn: 0.6171694	test: 0.5129748	best: 0.5174878 (168)	total: 3.31s	remaining: 4.92s
# bestTest = 0.5174877774
# bestIteration = 168
# Shrink model to first 169 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.1; total time=   4.1s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.4ms	remaining: 9.2s
# 100:	learn: 0.5719883	test: 0.5130375	best: 0.5143538 (92)	total: 1.99s	remaining: 7.84s
# 200:	learn: 0.6362113	test: 0.5174251	best: 0.5189921 (166)	total: 3.76s	remaining: 5.59s
# bestTest = 0.5189921023
# bestIteration = 166
# Shrink model to first 167 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.1; total time=   4.7s
# 0:	learn: 0.4961526	test: 0.4919769	best: 0.4919769 (0)	total: 18.3ms	remaining: 9.11s
# 100:	learn: 0.5222348	test: 0.5023192	best: 0.5028206 (99)	total: 1.85s	remaining: 7.3s
# 200:	learn: 0.5567436	test: 0.5114078	best: 0.5114078 (183)	total: 3.63s	remaining: 5.4s
# 300:	learn: 0.5797810	test: 0.5115958	best: 0.5123480 (274)	total: 5.26s	remaining: 3.48s
# 400:	learn: 0.6041401	test: 0.5191801	best: 0.5197443 (393)	total: 6.89s	remaining: 1.7s
# 499:	learn: 0.6305764	test: 0.5209979	best: 0.5218754 (496)	total: 8.48s	remaining: 0us
# bestTest = 0.5218753918
# bestIteration = 496
# Shrink model to first 497 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=10, learning_rate=0.05; total time=   9.0s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.4ms	remaining: 8.66s
# 100:	learn: 0.5188359	test: 0.5045130	best: 0.5045130 (97)	total: 1.7s	remaining: 6.71s
# 200:	learn: 0.5472785	test: 0.5110317	best: 0.5110317 (200)	total: 3.81s	remaining: 5.67s
# 300:	learn: 0.5712364	test: 0.5142284	best: 0.5142284 (300)	total: 5.57s	remaining: 3.69s
# bestTest = 0.5154820108
# bestIteration = 330
# Shrink model to first 331 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=10, learning_rate=0.05; total time=   7.6s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.5ms	remaining: 9.25s
# 100:	learn: 0.5229418	test: 0.5031967	best: 0.5046383 (96)	total: 1.86s	remaining: 7.34s
# 200:	learn: 0.5595497	test: 0.5122226	best: 0.5134136 (198)	total: 3.52s	remaining: 5.23s
# 300:	learn: 0.5883450	test: 0.5172371	best: 0.5179892 (273)	total: 5.14s	remaining: 3.4s
# 400:	learn: 0.6156769	test: 0.5207471	best: 0.5213740 (399)	total: 6.78s	remaining: 1.67s
# bestTest = 0.5223768334
# bestIteration = 406
# Shrink model to first 407 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=10, learning_rate=0.05; total time=   8.3s
# 0:	learn: 0.4961526	test: 0.4919769	best: 0.4919769 (0)	total: 17.7ms	remaining: 8.85s
# 100:	learn: 0.5622669	test: 0.5112824	best: 0.5115958 (97)	total: 2.04s	remaining: 8.05s
# bestTest = 0.516171493
# bestIteration = 138
# Shrink model to first 139 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=10, learning_rate=0.1; total time=   4.2s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.9ms	remaining: 8.95s
# 100:	learn: 0.5517632	test: 0.5089633	best: 0.5094647 (88)	total: 1.82s	remaining: 7.21s
# 200:	learn: 0.5987348	test: 0.5112824	best: 0.5124734 (194)	total: 3.57s	remaining: 5.32s
# 300:	learn: 0.6490818	test: 0.5174878	best: 0.5179892 (293)	total: 5.27s	remaining: 3.48s
# 400:	learn: 0.6946608	test: 0.5182399	best: 0.5221261 (377)	total: 6.9s	remaining: 1.7s
# bestTest = 0.5221261126
# bestIteration = 377
# Shrink model to first 378 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=10, learning_rate=0.1; total time=   7.9s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.3ms	remaining: 9.13s
# 100:	learn: 0.5618863	test: 0.5141030	best: 0.5141030 (100)	total: 1.69s	remaining: 6.67s
# 200:	learn: 0.6170695	test: 0.5154820	best: 0.5165476 (158)	total: 3.3s	remaining: 4.91s
# 300:	learn: 0.6646290	test: 0.5203711	best: 0.5223142 (282)	total: 5.25s	remaining: 3.47s
# bestTest = 0.5223141532
# bestIteration = 282
# Shrink model to first 283 iterations.
# [CV] END depth=8, iterations=500, l2_leaf_reg=10, learning_rate=0.1; total time=   6.4s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 18.1ms	remaining: 10.8s
# 100:	learn: 0.5316291	test: 0.5055785	best: 0.5055785 (100)	total: 1.85s	remaining: 9.15s
# 200:	learn: 0.5690412	test: 0.5137270	best: 0.5140404 (199)	total: 3.72s	remaining: 7.38s
# 300:	learn: 0.6065477	test: 0.5184907	best: 0.5194309 (273)	total: 5.47s	remaining: 5.43s
# 400:	learn: 0.6451636	test: 0.5197443	best: 0.5219381 (380)	total: 7.11s	remaining: 3.53s
# bestTest = 0.521938072
# bestIteration = 380
# Shrink model to first 381 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=5, learning_rate=0.05; total time=   8.1s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.8ms	remaining: 10.6s
# 100:	learn: 0.5250673	test: 0.5039489	best: 0.5041369 (98)	total: 1.7s	remaining: 8.41s
# 200:	learn: 0.5621253	test: 0.5092140	best: 0.5103422 (179)	total: 3.34s	remaining: 6.63s
# 300:	learn: 0.6006940	test: 0.5166729	best: 0.5166729 (300)	total: 5.35s	remaining: 5.32s
# 400:	learn: 0.6353680	test: 0.5170490	best: 0.5193682 (377)	total: 7.13s	remaining: 3.54s
# bestTest = 0.5193681835
# bestIteration = 377
# Shrink model to first 378 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=5, learning_rate=0.05; total time=   8.2s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.8ms	remaining: 11.3s
# 100:	learn: 0.5379768	test: 0.5036981	best: 0.5045130 (92)	total: 1.91s	remaining: 9.45s
# 200:	learn: 0.5743958	test: 0.5156074	best: 0.5159835 (182)	total: 3.7s	remaining: 7.34s
# bestTest = 0.5159834524
# bestIteration = 182
# Shrink model to first 183 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=5, learning_rate=0.05; total time=   4.8s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 17.8ms	remaining: 10.7s
# 100:	learn: 0.5763348	test: 0.5136016	best: 0.5155447 (89)	total: 1.73s	remaining: 8.54s
# 200:	learn: 0.6423311	test: 0.5201203	best: 0.5211859 (188)	total: 3.38s	remaining: 6.71s
# bestTest = 0.5211859095
# bestIteration = 188
# Shrink model to first 189 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=5, learning_rate=0.1; total time=   4.6s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.5ms	remaining: 10.5s
# 100:	learn: 0.5669405	test: 0.5167983	best: 0.5183653 (99)	total: 2.02s	remaining: 9.99s
# bestTest = 0.5211859095
# bestIteration = 146
# Shrink model to first 147 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=5, learning_rate=0.1; total time=   4.3s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18ms	remaining: 10.8s
# 100:	learn: 0.5801784	test: 0.5114705	best: 0.5127868 (93)	total: 1.84s	remaining: 9.07s
# 200:	learn: 0.6519071	test: 0.5168610	best: 0.5179265 (163)	total: 3.63s	remaining: 7.21s
# 300:	learn: 0.7160593	test: 0.5218754	best: 0.5235678 (282)	total: 5.37s	remaining: 5.33s
# bestTest = 0.526513727
# bestIteration = 345
# Shrink model to first 346 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=5, learning_rate=0.1; total time=   7.5s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 17.6ms	remaining: 10.6s
# 100:	learn: 0.5279705	test: 0.5011909	best: 0.5023818 (97)	total: 1.72s	remaining: 8.49s
# 200:	learn: 0.5660435	test: 0.5102796	best: 0.5114705 (181)	total: 3.38s	remaining: 6.7s
# 300:	learn: 0.5923618	test: 0.5114705	best: 0.5138523 (282)	total: 5.38s	remaining: 5.34s
# 400:	learn: 0.6248879	test: 0.5170490	best: 0.5183026 (391)	total: 7.16s	remaining: 3.55s
# bestTest = 0.51830262
# bestIteration = 391
# Shrink model to first 392 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=7, learning_rate=0.05; total time=   8.5s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.5ms	remaining: 10.5s
# 100:	learn: 0.5239107	test: 0.5067695	best: 0.5067695 (100)	total: 1.83s	remaining: 9.05s
# 200:	learn: 0.5531322	test: 0.5134136	best: 0.5144164 (184)	total: 3.63s	remaining: 7.2s
# bestTest = 0.5162968535
# bestIteration = 235
# Shrink model to first 236 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=7, learning_rate=0.05; total time=   5.6s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.6ms	remaining: 11.1s
# 100:	learn: 0.5285593	test: 0.5028206	best: 0.5039489 (97)	total: 1.72s	remaining: 8.49s
# 200:	learn: 0.5653559	test: 0.5132882	best: 0.5133509 (199)	total: 3.37s	remaining: 6.69s
# 300:	learn: 0.6000047	test: 0.5184907	best: 0.5191801 (252)	total: 5.47s	remaining: 5.43s
# bestTest = 0.5191801429
# bestIteration = 252
# Shrink model to first 253 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=7, learning_rate=0.05; total time=   6.1s
# 0:	learn: 0.4973564	test: 0.4927918	best: 0.4927918 (0)	total: 18.3ms	remaining: 11s
# 100:	learn: 0.5699146	test: 0.5114705	best: 0.5119719 (98)	total: 1.84s	remaining: 9.08s
# 200:	learn: 0.6259973	test: 0.5176131	best: 0.5197443 (164)	total: 3.6s	remaining: 7.15s
# bestTest = 0.5213739501
# bestIteration = 209
# Shrink model to first 210 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=7, learning_rate=0.1; total time=   5.2s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.5ms	remaining: 10.5s
# 100:	learn: 0.5561771	test: 0.5128494	best: 0.5136643 (95)	total: 1.8s	remaining: 8.89s
# 200:	learn: 0.6171694	test: 0.5129748	best: 0.5174878 (168)	total: 3.47s	remaining: 6.88s
# bestTest = 0.5174877774
# bestIteration = 168
# Shrink model to first 169 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=7, learning_rate=0.1; total time=   4.3s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.6ms	remaining: 11.2s
# 100:	learn: 0.5719883	test: 0.5130375	best: 0.5143538 (92)	total: 1.7s	remaining: 8.42s
# 200:	learn: 0.6362113	test: 0.5174251	best: 0.5189921 (166)	total: 3.33s	remaining: 6.62s
# bestTest = 0.5189921023
# bestIteration = 166
# Shrink model to first 167 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=7, learning_rate=0.1; total time=   4.2s
# 0:	learn: 0.4961526	test: 0.4919769	best: 0.4919769 (0)	total: 18.4ms	remaining: 11s
# 100:	learn: 0.5222348	test: 0.5023192	best: 0.5028206 (99)	total: 1.96s	remaining: 9.67s
# 200:	learn: 0.5567436	test: 0.5114078	best: 0.5114078 (183)	total: 3.83s	remaining: 7.59s
# 300:	learn: 0.5797810	test: 0.5115958	best: 0.5123480 (274)	total: 5.59s	remaining: 5.55s
# 400:	learn: 0.6041401	test: 0.5191801	best: 0.5197443 (393)	total: 7.35s	remaining: 3.65s
# 500:	learn: 0.6308833	test: 0.5216247	best: 0.5218754 (496)	total: 8.97s	remaining: 1.77s
# bestTest = 0.5218753918
# bestIteration = 496
# Shrink model to first 497 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=10, learning_rate=0.05; total time=  10.3s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.7ms	remaining: 10.6s
# 100:	learn: 0.5188359	test: 0.5045130	best: 0.5045130 (97)	total: 1.71s	remaining: 8.43s
# 200:	learn: 0.5472785	test: 0.5110317	best: 0.5110317 (200)	total: 3.35s	remaining: 6.65s
# 300:	learn: 0.5712364	test: 0.5142284	best: 0.5142284 (300)	total: 5.28s	remaining: 5.25s
# bestTest = 0.5154820108
# bestIteration = 330
# Shrink model to first 331 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=10, learning_rate=0.05; total time=   7.3s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18ms	remaining: 10.8s
# 100:	learn: 0.5229418	test: 0.5031967	best: 0.5046383 (96)	total: 1.91s	remaining: 9.42s
# 200:	learn: 0.5595497	test: 0.5122226	best: 0.5134136 (198)	total: 3.7s	remaining: 7.34s
# 300:	learn: 0.5883450	test: 0.5172371	best: 0.5179892 (273)	total: 5.37s	remaining: 5.33s
# 400:	learn: 0.6156769	test: 0.5207471	best: 0.5213740 (399)	total: 7s	remaining: 3.47s
# bestTest = 0.5223768334
# bestIteration = 406
# Shrink model to first 407 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=10, learning_rate=0.05; total time=   8.5s
# 0:	learn: 0.4961526	test: 0.4919769	best: 0.4919769 (0)	total: 18.1ms	remaining: 10.8s
# 100:	learn: 0.5622669	test: 0.5112824	best: 0.5115958 (97)	total: 1.7s	remaining: 8.39s
# bestTest = 0.516171493
# bestIteration = 138
# Shrink model to first 139 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=10, learning_rate=0.1; total time=   3.8s
# 0:	learn: 0.4932257	test: 0.4880281	best: 0.4880281 (0)	total: 17.4ms	remaining: 10.4s
# 100:	learn: 0.5517160	test: 0.5089633	best: 0.5094647 (88)	total: 1.97s	remaining: 9.74s
# 200:	learn: 0.5987112	test: 0.5141657	best: 0.5143538 (171)	total: 3.74s	remaining: 7.42s
# 300:	learn: 0.6473351	test: 0.5137270	best: 0.5168610 (295)	total: 5.58s	remaining: 5.54s
# bestTest = 0.5174250972
# bestIteration = 345
# Shrink model to first 346 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=10, learning_rate=0.1; total time=   7.8s
# 0:	learn: 0.4976161	test: 0.4922903	best: 0.4922903 (0)	total: 18.3ms	remaining: 11s
# 100:	learn: 0.5618863	test: 0.5141030	best: 0.5141030 (100)	total: 1.69s	remaining: 8.37s
# 200:	learn: 0.6170695	test: 0.5154820	best: 0.5165476 (158)	total: 3.34s	remaining: 6.63s
# 300:	learn: 0.6646290	test: 0.5203711	best: 0.5223142 (282)	total: 5.01s	remaining: 4.98s
# bestTest = 0.5223141532
# bestIteration = 282
# Shrink model to first 283 iterations.
# [CV] END depth=8, iterations=600, l2_leaf_reg=10, learning_rate=0.1; total time=   6.1s
# 0:	learn: 0.4953737	test: 0.4934186	best: 0.4934186 (0)	total: 20.4ms	remaining: 8.16s
# 100:	learn: 0.5553895	test: 0.5231290	best: 0.5231290 (100)	total: 1.96s	remaining: 5.79s
# 200:	learn: 0.6088906	test: 0.5272032	best: 0.5292090 (194)	total: 3.73s	remaining: 3.69s
# 300:	learn: 0.6566798	test: 0.5314655	best: 0.5337220 (278)	total: 5.54s	remaining: 1.82s
# bestTest = 0.5337219506
# bestIteration = 278
# Shrink model to first 279 iterations.
# Best Parameters: {'depth': 8, 'iterations': 400, 'l2_leaf_reg': 5, 'learning_rate': 0.1}
# Best Cross-Validation Accuracy: 0.466149536737772
# Test Set Accuracy: 0.47062879205736347
# Classification Report:
#                precision    recall  f1-score   support
#
#          1.0       0.67      0.26      0.38       417
#          2.0       0.50      0.07      0.13       394
#          3.0       0.34      0.30      0.32      1170
#          4.0       0.54      0.12      0.20      2350
#          5.0       0.48      0.90      0.63      2921
#
#     accuracy                           0.47      7252
#    macro avg       0.51      0.33      0.33      7252
# weighted avg       0.49      0.47      0.40      7252

# %%
def recommend_top_destinations(user_input, model, df_learning, le, top_n=10, threshold=0.7):
    destinations = df_learning[['VISIT_AREA_NM', 'VISIT_AREA_TYPE_CD']].drop_duplicates()
    destinations['VISIT_AREA_NM_CODE'] = le.transform(destinations['VISIT_AREA_NM'])

    prediction_data = []
    for _, row in destinations.iterrows():
        combined_input = user_input.copy()
        combined_input['VISIT_AREA_TYPE_CD'] = row['VISIT_AREA_TYPE_CD']
        combined_input['VISIT_AREA_NM_CODE'] = row['VISIT_AREA_NM_CODE']
        prediction_data.append(combined_input)

    prediction_df = pd.DataFrame(prediction_data, columns=cat_features_extended)
    proba = model.predict_proba(prediction_df)
    prob_5 = proba[:, 4]  # 5.0 확률

    recommendations = pd.DataFrame({
        'VISIT_AREA_NM': destinations['VISIT_AREA_NM'],
        'Probability_5.0': prob_5
    })
    return recommendations[recommendations['Probability_5.0'] >= threshold].nlargest(top_n, 'Probability_5.0')

# %%
proba = best_model.predict_proba(X_test)
test_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': best_model.predict(X_test).flatten(),
    'Prob_5.0': proba[:, 4]
})
test_5 = test_df[test_df['Actual'] == 5.0]
print("5.0 샘플 통계:")
print(test_5['Prob_5.0'].describe())
print("5.0 예측 비율:", (test_5['Predicted'] == 5.0).mean())

# 추가: 전체 테스트 셋의 5.0 확률 분포
print("\n전체 테스트 셋 5.0 확률 통계:")
print(test_df['Prob_5.0'].describe())
# Out:
# 5.0 샘플 통계:
# count    2921.000000
# mean        0.542599
# std         0.135862
# min         0.156269
# 25%         0.442283
# 50%         0.538692
# 75%         0.639121
# max         0.919522
# Name: Prob_5.0, dtype: float64
# 5.0 예측 비율: 0.9024306744265662
#
# 전체 테스트 셋 5.0 확률 통계:
# count    7252.000000
# mean        0.451783
# std         0.191623
# min         0.001103
# 25%         0.360545
# 50%         0.471795
# 75%         0.578717
# max         0.919522
# Name: Prob_5.0, dtype: float64

# %%
# 추천 예시
user_input = {
    'GENDER': 1, 'AGE_GRP': 30, 'TRAVEL_STYL_1': 1, 'TRAVEL_STYL_2': 2,
    'TRAVEL_STYL_3': 1, 'TRAVEL_STYL_4': 4, 'TRAVEL_STYL_5': 5,
    'TRAVEL_STYL_6': 3, 'TRAVEL_STYL_7': 6, 'TRAVEL_STYL_8': 2,
    'TRAVEL_MOTIVE_1': 1, 'TRAVEL_COMPANIONS_NUM': 2, 'TRAVEL_MISSION_INT': 1
}
for feature in cat_features_extended:
    print(f"{feature} 범위: {X[feature].min()} ~ {X[feature].max()}, 입력값: {user_input.get(feature, '없음')}")

recs = recommend_top_destinations(user_input, best_model, df_learning, le, threshold=0.0)

print("Top Recommendations for 5.0 (threshold=0.7):")
print(recs)
# Out:
# GENDER 범위: 0 ~ 1, 입력값: 1
# AGE_GRP 범위: 20 ~ 60, 입력값: 30
# TRAVEL_STYL_1 범위: 1 ~ 7, 입력값: 1
# TRAVEL_STYL_2 범위: 1 ~ 7, 입력값: 2
# TRAVEL_STYL_3 범위: 1 ~ 7, 입력값: 1
# TRAVEL_STYL_4 범위: 1 ~ 7, 입력값: 4
# TRAVEL_STYL_5 범위: 1 ~ 7, 입력값: 5
# TRAVEL_STYL_6 범위: 1 ~ 7, 입력값: 3
# TRAVEL_STYL_7 범위: 1 ~ 7, 입력값: 6
# TRAVEL_STYL_8 범위: 1 ~ 7, 입력값: 2
# TRAVEL_MOTIVE_1 범위: 1 ~ 10, 입력값: 1
# VISIT_AREA_TYPE_CD 범위: 1 ~ 8, 입력값: 없음
# TRAVEL_COMPANIONS_NUM 범위: 0 ~ 20, 입력값: 2
# TRAVEL_MISSION_INT 범위: 1 ~ 28, 입력값: 1
# VISIT_AREA_NM_CODE 범위: 0 ~ 10099, 입력값: 없음
# Top Recommendations for 5.0 (threshold=0.7):
#         VISIT_AREA_NM  Probability_5.0
# 45705         만리포해수욕장         0.660161
# 109419           서빈백사         0.657755
# 5610            서울대공원         0.657419
# 102161          따라비오름         0.657419
# 103810      거제식물원 정글돔         0.657419
# 113300  한라산국립공원 영실탐방로         0.657419
# 10994           서울대공원         0.652171
# 68067       유월드루지테마파크         0.652171
# 146362      거제식물원 정글돔         0.652171
# 760               덕수궁         0.651033

# %%
best_model.save_model('catboost_model.cbm')

# %%
import pickle
# LabelEncoder 저장
with open('../label_encoder.pkl', 'wb') as f:
    pickle.dump(le, f)
# df_learning 저장
df_learning.to_csv('df_learning.csv', index=False)

# %%
# CatBoost 모델 학습
model = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.1,
    depth=6,
    loss_function='MultiClass',
    eval_metric='Accuracy',
    random_seed=42,
    verbose=100
)
model.fit(X_train, y_train, cat_features=cat_features_extended, eval_set=(X_test, y_test))

# 전체 테스트 셋 성능 평가
y_pred = model.predict(X_test)
print("Full Test Set Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.4598460	test: 0.4600117	best: 0.4600117 (0)	total: 205ms	remaining: 3m 25s
# 100:	learn: 0.5368701	test: 0.5255400	best: 0.5255400 (100)	total: 12.6s	remaining: 1m 51s
# 200:	learn: 0.5619002	test: 0.5407180	best: 0.5411559 (186)	total: 25s	remaining: 1m 39s
# 300:	learn: 0.5821505	test: 0.5477233	best: 0.5477233 (287)	total: 37.6s	remaining: 1m 27s
# 400:	learn: 0.6032400	test: 0.5537069	best: 0.5537069 (400)	total: 50.4s	remaining: 1m 15s
# 500:	learn: 0.6205714	test: 0.5560420	best: 0.5564799 (498)	total: 1m 3s	remaining: 1m 2s
# 600:	learn: 0.6391068	test: 0.5564799	best: 0.5576474 (529)	total: 1m 15s	remaining: 50.4s
# 700:	learn: 0.6558543	test: 0.5580852	best: 0.5583771 (619)	total: 1m 28s	remaining: 37.9s
# 800:	learn: 0.6712884	test: 0.5576474	best: 0.5605663 (758)	total: 1m 41s	remaining: 25.3s
# 900:	learn: 0.6889116	test: 0.5608581	best: 0.5623176 (885)	total: 1m 54s	remaining: 12.6s
# 999:	learn: 0.7052213	test: 0.5631932	best: 0.5645067 (960)	total: 2m 7s	remaining: 0us
#
# bestTest = 0.5645067134
# bestIteration = 960
#
# Shrink model to first 961 iterations.
# Full Test Set Accuracy: 0.5645067133683596
# Classification Report:
#                precision    recall  f1-score   support
#
#          1.0       0.66      0.60      0.63       383
#          2.0       0.67      0.38      0.48       399
#          3.0       0.36      0.03      0.06       789
#          4.0       0.50      0.54      0.52      2329
#          5.0       0.59      0.75      0.66      2952
#
#     accuracy                           0.56      6852
#    macro avg       0.56      0.46      0.47      6852
# weighted avg       0.54      0.56      0.53      6852

# %%
# 추천 함수
def recommend_top_travel_destinations(user_input, model, df_learning, top_n=10):
    destinations = df_learning[['VISIT_AREA_NM', 'VISIT_AREA_TYPE_CD']].drop_duplicates()
    destinations['VISIT_AREA_NM_CODE'] = le.transform(destinations['VISIT_AREA_NM'])

    prediction_data = []
    for _, row in destinations.iterrows():
        combined_input = user_input.copy()
        combined_input['VISIT_AREA_TYPE_CD'] = row['VISIT_AREA_TYPE_CD']
        combined_input['VISIT_AREA_NM_CODE'] = row['VISIT_AREA_NM_CODE']
        prediction_data.append(combined_input)

    prediction_df = pd.DataFrame(prediction_data, columns=cat_features_extended)
    prediction_df[cat_features_extended] = prediction_df[cat_features_extended].astype('int32')

    proba = model.predict_proba(prediction_df)
    prob_5 = proba[:, 4]  # 5.0 확률 (인덱스 4)

    recommendations = pd.DataFrame({
        'VISIT_AREA_NM': destinations['VISIT_AREA_NM'],
        'VISIT_AREA_TYPE_CD': destinations['VISIT_AREA_TYPE_CD'],
        'Probability_5.0': prob_5
    })
    return recommendations.nlargest(top_n, 'Probability_5.0')

# %%
# 예시 사용자 입력
user_input = {
    'GENDER': 1, 'AGE_GRP': 3, 'TRAVEL_STYL_1': 1, 'TRAVEL_STYL_2': 2,
    'TRAVEL_STYL_3': 1, 'TRAVEL_STYL_4': 2, 'TRAVEL_STYL_5': 1,
    'TRAVEL_STYL_6': 1, 'TRAVEL_STYL_7': 1, 'TRAVEL_STYL_8': 2,
    'TRAVEL_MOTIVE_1': 1, 'TRAVEL_COMPANIONS_NUM': 2, 'TRAVEL_MISSION_INT': 1
}

# 추천 실행
recommendations = recommend_top_travel_destinations(user_input, model, df_learning)
print("\nTop 10 Recommended Destinations:")
print(recommendations)

# 테스트 셋 샘플 예측
n_samples = 10
sample_indices = np.random.choice(X_test.index, size=n_samples, replace=False)
X_test_sample = X_test.loc[sample_indices]
y_test_sample = y_test.loc[sample_indices]

y_pred_sample = model.predict(X_test_sample)
proba_sample = model.predict_proba(X_test_sample)
prob_5_sample = proba_sample[:, 4]

comparison_df = pd.DataFrame({
    'Actual_Satisfaction': y_test_sample,
    'Predicted_Satisfaction': y_pred_sample.flatten(),
    'Probability_5.0': prob_5_sample
}, index=sample_indices)
# Out:
# Top 10 Recommended Destinations:
#        VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 31651   태화강국가정원 십리대숲                   7         0.408533
# 103015       한라산국립공원                   1         0.403646
# 760              덕수궁                   2         0.391664
# 70438    전북대학교 전주캠퍼스                   7         0.381596
# 106101       서우봉 산책로                   7         0.379590
# 115855            우도                   7         0.378461
# 110989         스누피가든                   7         0.371141
# 102878        쏠비치 진도                   7         0.367684
# 30773   태화강국가정원 십리대숲                   1         0.363457
# 68313         담양관방제림                   7         0.361022

# %%
print("\nTest Set Sample Predictions vs Actual:")
print(comparison_df)

print("\nRecommendations for Each Sample:")
for idx in sample_indices:
    user_input = X_test_sample.loc[idx].to_dict()
    user_input_clean = {k: v for k, v in user_input.items() if k != 'VISIT_AREA_TYPE_CD'}
    recommendations = recommend_top_travel_destinations(user_input_clean, model, df_learning, top_n=3)
    print(f"\nSample {idx}:")
    print(f"Actual: {y_test_sample.loc[idx]}, Predicted: {y_pred_sample[sample_indices.tolist().index(idx)]}, Prob 5.0: {prob_5_sample[sample_indices.tolist().index(idx)]:.4f}")
    print("Top 3 Recommended Destinations:")
    print(recommendations)
# Out:
# Test Set Sample Predictions vs Actual:
#        Actual_Satisfaction  Predicted_Satisfaction  Probability_5.0
# 11227                  4.0                     5.0         0.667212
# 25756                  3.0                     4.0         0.343412
# 13022                  4.0                     5.0         0.458636
# 26540                  2.0                     4.0         0.163053
# 7212                   5.0                     5.0         0.850229
# 13722                  5.0                     5.0         0.603735
# 22926                  5.0                     5.0         0.797065
# 30408                  4.0                     4.0         0.228389
# 8087                   4.0                     5.0         0.579189
# 10917                  5.0                     5.0         0.675757
#
# Recommendations for Each Sample:
#
# Sample 11227:
# Actual: 4.0, Predicted: [5.], Prob 5.0: 0.6672
# Top 3 Recommended Destinations:
#        VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 113270       한라산국립공원                   2         0.866783
# 760              덕수궁                   2         0.862161
# 3883             월정교                   2         0.859735
#
# Sample 25756:
# Actual: 3.0, Predicted: [4.], Prob 5.0: 0.3434
# Top 3 Recommended Destinations:
#        VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 32561    파크로쉬리조트앤웰니스                   5         0.635190
# 74945    라마다 여수해상짚트랙                   5         0.602866
# 150820       목장카페 밭디                   5         0.594677
#
# Sample 13022:
# Actual: 4.0, Predicted: [5.], Prob 5.0: 0.4586
# Top 3 Recommended Destinations:
#      VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 2700        남산서울타워                   3         0.705762
# 1303       마이아트뮤지엄                   3         0.682520
# 8057           창경궁                   3         0.676802
#
# Sample 26540:
# Actual: 2.0, Predicted: [4.], Prob 5.0: 0.1631
# Top 3 Recommended Destinations:
#       VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 76588        전주덕진공원                   3         0.582480
# 6098          서울대공원                   3         0.578173
# 54749   연세대학교 미래캠퍼스                   3         0.563773
#
# Sample 7212:
# Actual: 5.0, Predicted: [5.], Prob 5.0: 0.8502
# Top 3 Recommended Destinations:
#       VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 32561   파크로쉬리조트앤웰니스                   5         0.931577
# 36460      하이원 워터월드                   5         0.929570
# 30031       송도센트럴파크                   5         0.928196
#
# Sample 13722:
# Actual: 5.0, Predicted: [5.], Prob 5.0: 0.6037
# Top 3 Recommended Destinations:
#        VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 103446         포도뮤지엄                   3         0.667997
# 102185         스누피가든                   3         0.662816
# 31727            대왕암                   2         0.658750
#
# Sample 22926:
# Actual: 5.0, Predicted: [5.], Prob 5.0: 0.7971
# Top 3 Recommended Destinations:
#        VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 32561    파크로쉬리조트앤웰니스                   5         0.872831
# 120966       한라산국립공원                   7         0.859304
# 74945    라마다 여수해상짚트랙                   5         0.858209
#
# Sample 30408:
# Actual: 4.0, Predicted: [4.], Prob 5.0: 0.2284
# Top 3 Recommended Destinations:
#        VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 68867           광한루원                   3         0.532775
# 102185         스누피가든                   3         0.512967
# 105451         스누피가든                   6         0.505900
#
# Sample 8087:
# Actual: 4.0, Predicted: [5.], Prob 5.0: 0.5792
# Top 3 Recommended Destinations:
#       VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 2700         남산서울타워                   3         0.870746
# 35549   KT&G상상마당 부산                   3         0.863828
# 45877    대구삼성라이온즈파크                   3         0.863828
#
# Sample 10917:
# Actual: 5.0, Predicted: [5.], Prob 5.0: 0.6758
# Top 3 Recommended Destinations:
#       VISIT_AREA_NM  VISIT_AREA_TYPE_CD  Probability_5.0
# 2174         캐리비안베이                   6         0.777821
# 10731      문경새재도립공원                   1         0.776736
# 30773  태화강국가정원 십리대숲                   1         0.774345
